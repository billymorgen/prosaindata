# %% [markdown]
# # Mahasiswa

# %%
pip install requests beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)

# %%
import requests

# URL Studentsite UG
url_ss = 'https://pta.trunojoyo.ac.id/'

laman_ss = requests.get(url_ss)
# jika sukses, maka status query ini adalah 200, alias OK
print(f'Status GET laman SS UG: {laman_ss.status_code}')
# Out:
# Status GET laman SS UG: 200

# %%
# cetak HTML
print(laman_ss.content)
# Out:
# b'<!DOCTYPE html>\n\n<html>\n\n<head>\n\t<meta charset="utf-8"/>\n\t<title>Portal Tugas Akhir Univ. Trunojoyo</title>\n\t<link rel="stylesheet" href="https://pta.trunojoyo.ac.id/css/reset.css" type="text/css"/>\n\t<link rel="stylesheet" href="https://pta.trunojoyo.ac.id/css/style.css" type="text/css"/>\n\t<link rel="stylesheet" href="https://pta.trunojoyo.ac.id/css/960_12_col.css" type="text/css"/>\n\t<link rel="stylesheet" media="screen" href="https://pta.trunojoyo.ac.id/css/smoothness/jquery-ui-1.8.18.custom.css" />\n\n\t<!--[if lte IE 8]> <link rel="stylesheet" type="text/css" href="css/ie.css" /> <![endif]-->\n\t\n    <!-- favicon -->\n    <link rel="shortcut icon" type="image/x-icon" href="https://pta.trunojoyo.ac.id/images/favicon.ico"/>\n\t\n\t<!-- javascript -->\n\t<script type="text/javascript" src="https://pta.trunojoyo.ac.id/js/jquery-1.7.1.min.js"></script>\n\t<script type="text/javascript" src="https://pta.trunojoyo.ac.id/js/jquery.validate.js"></script>\n\t<script type="text/javascript" src="https://pta.trunojoyo.ac.id/js/jquery.form.js"></script>\n\t<script type="text/javascript" src="https://pta.trunojoyo.ac.id/js/datepicker/js/jquery-ui-1.8.16.custom.min.js"></script>\n\t<script type="text/javascript" src="https://pta.trunojoyo.ac.id/js/datepicker/js/jquery.ui.datepicker-id.js"></script>\n\t\n\t<!--[if lte IE 7]>\n\t<script type="text/javascript">\n\t\t// Make menu 2 level, fix for IE < 7\n\t\t$(document).ready(function(){\n\t\t\t$("#sidebar ul li").mouseover(function(){\n\t\t\t\tvar w = $(this).width()+\'px\';\t\t\t\t\n\t\t\t\t$(this).find("ul").css(\'left\',w);\n\t\t\t});\n\t\t\t$("#sidebar ul li").mouseout(function(){\n\t\t\t\t$(this).find("ul").css(\'left\',\'-9999px\');\n\t\t\t});\n\t\t});\n\t</script>\n\t <![endif]-->\n\t<meta name="google-site-verification" content="fjT5XAQAmDWjsF1Tn4-az3Hum8OJQjfh1kqmrjecf00" /> \n</head>\n\n<body>\n\t<div id="transBox">\n\t\t<img src="https://pta.trunojoyo.ac.id/images/loading.gif">\n\t</div>\n\t\n\t<div id="wrapper">\n\t\t<header id="header">\n\t\t\t<a id="logo" href="index.html"><img src="https://pta.trunojoyo.ac.id/images/logo.png" alt="Mirage"/></a>\n\t\t\t\n\t\t\t<div id="counts">\n\t\t\t\t\t\t\t\t<div><a href="#"><span class="number">14678</span><span class="follow">Journal</span></a></div>\t\t\t\t\n\t\t\t\t<!--\n\t\t\t\t<div><a href="#"><span class="number">877</span><span class="like">Like</span>s</a></div>\n\t\t\t\t<hr/>\n\t\t\t\t<div><a href="#"><span class="number">7.418</span><span class="subscribe">Subscribe</span>rs</a></div>\n\t\t\t\t-->\n\t\t\t</div>\n\t\t\t\n\t\t\t<nav>\n\t\t\t\t<ul id="topnav">\n\t\t\t\t\t<li><a href="https://pta.trunojoyo.ac.id/"><span>Beranda</span></a></li>\n\t\t\t\t\t<li><a href="https://pta.trunojoyo.ac.id/c_search/"><span>Pencarian</span></a></li>\n\t\t\t\t\t<li><a href="https://pta.trunojoyo.ac.id/c_template/"><span>Download</span></a></li>\n\t\t\t\t\t<li><a target="_blank" href="https://library.trunojoyo.ac.id/detil.php?id=23"><span>Petunjuk Upload</span></a></li>\n<!--\t\t\t\t\t\n\t\t\t\t\t<li><a href="c_sugestion/"><span>Saran & Kritik</span></a></li>\n-->\t\t\t\t\n\t\t\t\t\t<li><a href="https://pta.trunojoyo.ac.id/c_contact/"><span>Kontak</span></a></li>\t\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t</ul>\n\t\t\t</nav>\n\t\t\t\n\t\t</header>\n\n\t\t<div id="content" class="has_sidebar right">\n\t\t\t<div id="begin" class="inner">\n\n\n\t\t\t\t<h2>Daftar Karya Ilmiah</h2>\n</div> <!-- begin -->\n<div id="content_journal">\n\n\t\t\t<ul class="items list_style">\n\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t<li data-id="id-1" data-cat="#luxury">\n\t\t\t\t\t<!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->\n\t\t\t\t\t<div style="float:left; width:auto">\n\t\t\t\t\t\t<a class="title" href="#">STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN</a>\n\t\t\t\t\t\t<div style="paddi ...

# %%
from bs4 import BeautifulSoup  # ini sebaiknya ditaruh di bagian atas file
soup = BeautifulSoup(laman_ss.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Portal Tugas Akhir Univ. Trunojoyo
#   </title>
#   <link href="https://pta.trunojoyo.ac.id/css/reset.css" rel="stylesheet" type="text/css"/>
#   <link href="https://pta.trunojoyo.ac.id/css/style.css" rel="stylesheet" type="text/css"/>
#   <link href="https://pta.trunojoyo.ac.id/css/960_12_col.css" rel="stylesheet" type="text/css"/>
#   <link href="https://pta.trunojoyo.ac.id/css/smoothness/jquery-ui-1.8.18.custom.css" media="screen" rel="stylesheet"/>
#   <!--[if lte IE 8]> <link rel="stylesheet" type="text/css" href="css/ie.css" /> <![endif]-->
#   <!-- favicon -->
#   <link href="https://pta.trunojoyo.ac.id/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!-- javascript -->
#   <script src="https://pta.trunojoyo.ac.id/js/jquery-1.7.1.min.js" type="text/javascript">
#   </script>
#   <script src="https://pta.trunojoyo.ac.id/js/jquery.validate.js" type="text/javascript">
#   </script>
#   <script src="https://pta.trunojoyo.ac.id/js/jquery.form.js" type="text/javascript">
#   </script>
#   <script src="https://pta.trunojoyo.ac.id/js/datepicker/js/jquery-ui-1.8.16.custom.min.js" type="text/javascript">
#   </script>
#   <script src="https://pta.trunojoyo.ac.id/js/datepicker/js/jquery.ui.datepicker-id.js" type="text/javascript">
#   </script>
#   <!--[if lte IE 7]>
# 	<script type="text/javascript">
# 		// Make menu 2 level, fix for IE < 7
# 		$(document).ready(function(){
# 			$("#sidebar ul li").mouseover(function(){
# 				var w = $(this).width()+'px';
# 				$(this).find("ul").css('left',w);
# 			});
# 			$("#sidebar ul li").mouseout(function(){
# 				$(this).find("ul").css('left','-9999px');
# 			});
# 		});
# 	</script>
# 	 <![endif]-->
#   <meta content="fjT5XAQAmDWjsF1Tn4-az3Hum8OJQjfh1kqmrjecf00" name="google-site-verification"/>
#  </head>
#  <body>
#   <div id="transBox">
#    <img src="https://pta.trunojoyo.ac.id/images/loading.gif"/>
#   </div>
#   <div id="wrapper">
#    <header id="header">
#     <a href="index.html" id="logo">
#      <img alt="Mirage" src="https://pta.trunojoyo.ac.id/images/logo.png"/>
#     </a>
#     <div id="counts">
#      <div>
#       <a href="#">
#        <span class="number">
#         14678
#        </span>
#        <span class="follow">
#         Journal
#        </span>
#       </a>
#      </div>
#      <!--
# 				<div><a href="#"><span class="number">877</span><span class="like">Like</span>s</a></div>
# 				<hr/>
# 				<div><a href="#"><span class="number">7.418</span><span class="subscribe">Subscribe</span>rs</a></div>
# 				-->
#     </div>
#     <nav>
#      <ul id="topnav">
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/">
#         <span>
#          Beranda
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/">
#         <span>
#          Pencarian
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_template/">
#         <span>
#          Download
#         </span>
#        </a>
#       </li>
#       <li>
#        <a href="https://library.trunojoyo.ac.id/detil.php?id=23" target="_blank">
#         <span>
#          Petunjuk Upload
#         </span>
#        </a>
#       </li>
#       <!--
# 					<li><a href="c_sugestion/"><span>Saran & Kritik</span></a></li>
# -->
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_contact/">
#         <span>
#          Kontak
#         </span>
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </header>
#    <div class="has_sidebar right" id="content">
#     <div class="inner" id="begin">
#      <h2>
#       Daftar Karya Ilmiah
#      </h2>
#     </div>
#     <!-- begin -->
#     <div id="content_journal">
#      <ul class="items list_style">
#       <li data-cat="#luxury" data-id="id-1">
#        <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
#        <div style="float:left; width:auto">
#         <a class="title" href="#">
#          STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN
#         </a>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Penulis : Mohammad Maskur
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing I : Dr. Akhmad Farid, S.Pi., MT
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing II :Dr. Apri Arisandi, S.Pi., M.Si
#          </span>
#         </div>
#        </div>
#        <div style="clear:both;">
#        </div>
#        <div style="margin: 15px 15px 15px 15px;">
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraksi
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           Makanan dan minuman khas merupakan ciri dari kekayaan sumberdaya alam dari suatu daerah, pentingnya memaksimalkan pariwisata Pulau Giligenting ditunjang dengan…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraction
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           Typical food and drinks are characteristic of the richness of natural resources of an area, the importance of maximizing Giligenting…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/170361100003">
#           <span>
#            Selengkapnya
#           </span>
#           <img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/>
#          </a>
#         </div>
#        </div>
#       </li>
#       <li data-cat="#luxury" data-id="id-1">
#        <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
#        <div style="float:left; width:auto">
#         <a class="title" href="#">
#          PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013
#         </a>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Penulis : Moch. Steven
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing I : Dr. Wartiningsih, S.H., M.Hum
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing II :
#          </span>
#         </div>
#        </div>
#        <div style="clear:both;">
#        </div>
#        <div style="margin: 15px 15px 15px 15px;">
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraksi
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           ABSTRAK
# Akhir-akhir ini semakin maraknya pencurian kayu milik negara di sekitar hutan oleh masyarakat. akan tetapi perumusan sanksi pidana dalam…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraction
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           ABSTRACK
# Lately, there has been more and more rampant robbery of state timber around the forest by the community. However,…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/170111100053">
#           <span>
#            Selengkapnya
#           </span>
#           <img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/>
#          </a>
#         </div>
#        </div>
#       </li>
#       <li data-cat="#luxury" data-id="id-1">
#        <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
#        <div style="float:left; width:auto">
#         <a class="title" href="#">
#          Peran Teor Motivasi Herzberg Sebagai Mediator Self Efficacy, Lingkungan Kerja Dalam Meningkatkan Prestasi Kerja Pegawai ( Kantor Jasa Penilai Publik Guntur Eki Andri dan Rekan Kota Surabaya )
#         </a>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Penulis : Widha Deby Andrea
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing I : Mochammad Isa Anshori, S.E., M.Si.
#          </span>
#         </div>
#         <div style="padding:2px 2px 2px 2px;">
#          <span>
#           Dosen Pembimbing II :
#          </span>
#         </div>
#        </div>
#        <div style="clear:both;">
#        </div>
#        <div style="margin: 15px 15px 15px 15px;">
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraksi
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           Penelitian ini bertujuan untuk dapat mengetahui tentang pengaruh motivasi kerja sebagai mediator self efficacy dan lingkungan kerja terhadap prestasi kerja…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <b>
#           Abstraction
#          </b>
#         </div>
#         <div>
#          <p align="justify">
#           This study aims to find out about the effect of work motivation as a mediator of self efficacy and work…
#          </p>
#         </div>
#         <div style="margin: 25px 0px 15px 0px;">
#          <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/160211100116">
#           <span>
#            Selengkapnya
#           </span>
#           <img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/>
#          </a>
#         </div>
#        </div>
#       </li>
#      </ul>
#      <div class="inner" id="end">
#       <ol class="pagination">
#        <li>
#         <a class="pag_button selected">
#          1
#         </a>
#        </li>
#        <li>
#         <a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/2">
#          2
#         </a>
#        </li>
#        <li>
#         <a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/3">
#          3
#         </a>
#        </li>
#        <li>
#         <a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/2">
#          &gt;
#         </a>
#        </li>
#        <li>
#         <a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/4893">
#          »
#         </a>
#        </li>
#       </ol>
#      </div>
#      <!-- end -->
#     </div>
#    </div>
#    <!-- content -->
#    <div class="left" id="sidebar">
#     <div class="box sidebar_nav">
#      <h5>
#       Journal
#      </h5>
#      <ul>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/1">
#         Hukum
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/1">
#           Ilmu Hukum
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/24">
#           Magister Ilmu Hukum
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/2">
#         Pertanian
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/2">
#           Teknologi Industri Pertanian
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/3">
#           Agribisnis
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/4">
#           Agroteknologi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/5">
#           Ilmu Kelautan
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/35">
#           Manajemen Sumberdaya Perairan
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/3">
#         Ekonomi
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/6">
#           Ekonomi Pembangunan
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/7">
#           Manajemen
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/8">
#           Akuntansi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/21">
#           Akuntansi Sektor Publik
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/22">
#           Magister Manajemen
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/25">
#           Magister Akuntansi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/26">
#           D3 Enterpreneurship
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/4">
#         Teknik
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/9">
#           Teknik Industri
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/10">
#           Teknik Informatika
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/11">
#           Manajemen Informatika
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/19">
#           Teknik Multimedia Dan Jaringan
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/20">
#           Mekatronika
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/23">
#           Teknik Elektro
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/31">
#           Sistem Informasi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/32">
#           Teknik Mesin
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/33">
#           Teknik Mekatronika
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/5">
#         Ilmu Sosial Dan Ilmu Budaya
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/12">
#           Sosiologi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/13">
#           Ilmu Komunikasi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/14">
#           Psikologi
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/15">
#           Sastra Inggris
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/6">
#         Ilmu-ilmu Keislaman
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/16">
#           Ekonomi Syariah
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/17">
#           Hukum Bisnis Syariah
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/7">
#         Ilmu Pendidikan
#        </a>
#        <ul>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/18">
#           Pgsd
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/27">
#           Pendidikan Bhs Dan Sastra Indonesia
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/28">
#           Pendidikan Informatika
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/29">
#           Pendidikan Ipa
#          </a>
#         </li>
#         <li>
#          <a href="https://pta.trunojoyo.ac.id/c_search/byprod/30">
#           Pgpaud
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- navigation box -->
#     <div class="box inner">
#      <h5>
#       Total Jurnal
#      </h5>
#      <ul class="sidebar_list">
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/1">
#         Hukum
#        </a>
#        <span>
#         1485
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/2">
#         Pertanian
#        </a>
#        <span>
#         2178
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/3">
#         Ekonomi
#        </a>
#        <span>
#         2889
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/4">
#         Teknik
#        </a>
#        <span>
#         2299
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/5">
#         Ilmu Sosial Dan Ilmu Budaya
#        </a>
#        <span>
#         2533
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/6">
#         Ilmu-ilmu Keislaman
#        </a>
#        <span>
#         975
#        </span>
#       </li>
#       <li>
#        <a href="https://pta.trunojoyo.ac.id/c_search/byfac/7">
#         Ilmu Pendidikan
#        </a>
#        <span>
#         2308
#        </span>
#       </li>
#      </ul>
#     </div>
#     <!-- categories box -->
#     <div class="box inner">
#      <h5>
#       Login
#      </h5>
#      <span>
#       Gunakan username dan password siakad Anda.
#      </span>
#      <div>
#       <script src="https://pta.trunojoyo.ac.id/js/ardizorro-md5.js" type="text/javascript">
#       </script>
#       <form action="https://pta.trunojoyo.ac.id/c_login" id="flogin" method="post">
#        <input class="input_text required" id="username" name="username" placeholder="username" type="text"/>
#        <input class="input_text required" id="password" name="pass" placeholder="password" type="password"/>
#        <input id="token" type="hidden" value="d1f39bded52f21aa8f7221ade887aae1"/>
#        <input id="pswd" name="password" type="hidden"/>
#        <div style="margin:5px 0 0 3px;">
#         <button class="green button" style="height:25px;" type="submit">
#          Login
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/icons/lock.png"/>
#         </button>
#        </div>
#       </form>
#      </div>
#      <script type="text/javascript">
#       $(document).ready(function() {
# 					$("#flogin").validate();
# 				});
#      </script>
#     </div>
#     <!-- advert box -->
#     <div class="box inner">
#      <h5>
#       Link
#      </h5>
#      <ul class="sidebar_list">
#       <li>
#        <a href="http://trunojoyo.ac.id" target="_blank">
#         www.trunojoyo.ac.id
#        </a>
#       </li>
#       <li>
#        <a href="http://e-journal.dikti.go.id" target="_blank">
#         http://e-journal.dikti.go.id
#        </a>
#       </li>
#      </ul>
#     </div>
#     <!-- categories box -->
#    </div>
#    <footer id="footer">
#     <div class="container_12">
#      <div style="float:left; width:550px; padding:10px;">
#       <h4>
#        About eJournal
#       </h4>
#       <p>
#        Electronic journals, also known as ejournals, e-journals are scholarly journals or intellectual magazines that can be accessed via electronic transmission. In practice, this means that they are usually published on the Web. They are a specialized form of electronic document: they have the purpose of providing material for academic research and study, and they are formatted approximately like journal articles in traditional printed journals.
#       </p>
#      </div>
#      <div style="float:left; width:330px; padding:10px;">
#       <h4>
#        Follow us!
#       </h4>
#       <ul class="socials">
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/twitter_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/facebook_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/rss_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/google_plus_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/dribbble_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/vimeo_32.png"/>
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          <img alt="" src="https://pta.trunojoyo.ac.id/images/social/youtube_32.png"/>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <hr/>
#     <span id="copyright">
#      Copyright © 2012 PUSAT KOMPUTER Universitas Trunojoyo Madura. All Rights Reserved.
#     </span>
#    </footer>
#   </div>
#   <!-- wrapper -->
#   <script type="text/javascript">
#    function LoginPerpus() {
# 	$("#FloginPerpus").submit();
#   }
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-30717387-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#  </body>
# </html>

# %%
# ambil semua elemen tertentu ke dalam list
kontainer_berita = soup.find_all('div', id="content_journal")
print(kontainer_berita)
# Out:
# [<div id="content_journal">
# <ul class="items list_style">
# <li data-cat="#luxury" data-id="id-1">
# <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
# <div style="float:left; width:auto">
# <a class="title" href="#">STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN</a>
# <div style="padding:2px 2px 2px 2px;"><span>Penulis : Mohammad Maskur</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing I : Dr. Akhmad Farid, S.Pi., MT</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing II :Dr. Apri Arisandi, S.Pi., M.Si</span></div>
# </div>
# <div style="clear:both;"></div>
# <div style="margin: 15px 15px 15px 15px;">
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraksi</b></div>
# <div>
# <p align="justify">Makanan dan minuman khas merupakan ciri dari kekayaan sumberdaya alam dari suatu daerah, pentingnya memaksimalkan pariwisata Pulau Giligenting ditunjang dengan…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraction</b></div>
# <div>
# <p align="justify">Typical food and drinks are characteristic of the richness of natural resources of an area, the importance of maximizing Giligenting…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;">
# <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/170361100003"><span>Selengkapnya</span><img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/></a>
# </div>
# </div>
# </li>
# <li data-cat="#luxury" data-id="id-1">
# <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
# <div style="float:left; width:auto">
# <a class="title" href="#">PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013</a>
# <div style="padding:2px 2px 2px 2px;"><span>Penulis : Moch. Steven</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing I : Dr. Wartiningsih, S.H., M.Hum</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing II :</span></div>
# </div>
# <div style="clear:both;"></div>
# <div style="margin: 15px 15px 15px 15px;">
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraksi</b></div>
# <div>
# <p align="justify">ABSTRAK
# Akhir-akhir ini semakin maraknya pencurian kayu milik negara di sekitar hutan oleh masyarakat. akan tetapi perumusan sanksi pidana dalam…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraction</b></div>
# <div>
# <p align="justify">ABSTRACK
# Lately, there has been more and more rampant robbery of state timber around the forest by the community. However,…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;">
# <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/170111100053"><span>Selengkapnya</span><img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/></a>
# </div>
# </div>
# </li>
# <li data-cat="#luxury" data-id="id-1">
# <!-- <div class="preview" style="float:left;"><a href="#" class="frame"><img src="https://pta.trunojoyo.ac.id/images/portfolio/06.jpg" alt=""/></a></div> -->
# <div style="float:left; width:auto">
# <a class="title" href="#">Peran Teor Motivasi Herzberg Sebagai Mediator Self Efficacy, Lingkungan Kerja Dalam Meningkatkan Prestasi Kerja Pegawai ( Kantor Jasa Penilai Publik Guntur Eki Andri dan Rekan Kota Surabaya )</a>
# <div style="padding:2px 2px 2px 2px;"><span>Penulis : Widha Deby Andrea</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing I : Mochammad Isa Anshori, S.E., M.Si.</span></div>
# <div style="padding:2px 2px 2px 2px;"><span>Dosen Pembimbing II :</span></div>
# </div>
# <div style="clear:both;"></div>
# <div style="margin: 15px 15px 15px 15px;">
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraksi</b></div>
# <div>
# <p align="justify">Penelitian ini bertujuan untuk dapat mengetahui tentang pengaruh motivasi kerja sebagai mediator self efficacy dan lingkungan kerja terhadap prestasi kerja…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;"><b>Abstraction</b></div>
# <div>
# <p align="justify">This study aims to find out about the effect of work motivation as a mediator of self efficacy and work…</p>
# </div>
# <div style="margin: 25px 0px 15px 0px;">
# <a class="gray button" href="https://pta.trunojoyo.ac.id/welcome/detail/160211100116"><span>Selengkapnya</span><img alt="" src="https://pta.trunojoyo.ac.id/images/button/forward.png"/></a>
# </div>
# </div>
# </li>
# </ul>
# <div class="inner" id="end">
# <ol class="pagination">
# <li><a class="pag_button selected">1</a></li><li><a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/2">2</a></li><li><a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/3">3</a></li><li><a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/2">&gt;</a></li><li><a class="pag_button" href="https://pta.trunojoyo.ac.id/welcome/index/4893">»</a></li>
# </ol>
# </div> <!-- end -->
# </div>]

# %%
judul_list = []
ringkasan_list = []

for berita in kontainer_berita:
    for judul in berita.find_all('div', style="float:left; width:auto"):
        judul_string = judul.get_text()
        # buang spasi yang tidak diperlukan
        judul_rapi = ' '.join(str(judul_string).strip().split()) 
        print(judul_rapi)
        # append judul ke list
        judul_list.append(judul_rapi)
# Out:
# STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN Penulis : Mohammad Maskur Dosen Pembimbing I : Dr. Akhmad Farid, S.Pi., MT Dosen Pembimbing II :Dr. Apri Arisandi, S.Pi., M.Si
# PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013 Penulis : Moch. Steven Dosen Pembimbing I : Dr. Wartiningsih, S.H., M.Hum Dosen Pembimbing II :
# Peran Teor Motivasi Herzberg Sebagai Mediator Self Efficacy, Lingkungan Kerja Dalam Meningkatkan Prestasi Kerja Pegawai ( Kantor Jasa Penilai Publik Guntur Eki Andri dan Rekan Kota Surabaya ) Penulis : Widha Deby Andrea Dosen Pembimbing I : Mochammad Isa Anshori, S.E., M.Si. Dosen Pembimbing II :
