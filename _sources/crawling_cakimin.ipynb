# %% [markdown]
# # Cakimin

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
path = "gdrive/MyDrive/"
# Out:
# Mounted at /content/gdrive

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "Cak Imin"
tweets = []
limit = 5000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])
df.to_csv(path+'CrawlingTweetCak.csv', index=None, header=True)
print(df)



# to save to csv
# df.to_csv('tweets.csv')
# Out:
# <ipython-input-9-82a006a34f60>:16: FutureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
# <ipython-input-9-82a006a34f60>:16: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content])
#                           Date             User  \
# 0    2023-02-22 07:29:24+00:00  ahmadhellishfau
# 1    2023-02-22 07:19:28+00:00     nickrasyidsr
# 2    2023-02-22 07:17:44+00:00    rmp_officials
# 3    2023-02-22 07:14:21+00:00       billy4riez
# 4    2023-02-22 07:07:33+00:00          rmol_id
# ...                        ...              ...
# 4995 2023-01-24 10:27:17+00:00     genx36545403
# 4996 2023-01-24 10:27:15+00:00      enjoyjoni88
# 4997 2023-01-24 10:27:01+00:00     Emmayantiiii
# 4998 2023-01-24 10:24:17+00:00     Emmayantiiii
# 4999 2023-01-24 10:23:29+00:00          jalaprt
#
#                                                   Tweet
# 0     #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# 1     Kata Habis Ali Zainal Abidin Assegaf berarti s...
# 2     Beda kalo Mbah Sujiwo Tejo yang pimpin forum; ...
# 3     Respons Santai Cak Imin soal Gus Yahya Sebut W...
# 4     Jika Prabowo Bersanding dengan Puan, Cak Imin ...
# ...                                                 ...
# 4995  Ketua Umum Partai Gerindra Prabowo Subianto da...
# 4996  Peduli Perempuan dan Anak\nPartai Kebangkitan ...
# 4997         Mantap Cak Imin... https://t.co/JkylCBAtVi
# 4998  Mantap Cak Imin...pwrjuangannya. https://t.co/...
# 4999  Terima kasih Cak Imin atas dukungannya mendoro...
#
# [5000 rows x 3 columns]
